# %%
import h5py
import os
import json
import shutil
from extratorFeatures import *

# %%
PROGRESS_FILE = "Datasets/progressDataset.json"
ANNOTATIONS_FOLDER = "Anotacoes_Texto/"
INCOMPLETE_SUFFIX = "_incompleto.txt"
COMPLETE_SUFFIX = "_completo.txt"
NUM_FEATURES = 15

def gerar_nome_base_anotacao(caminho_imagem):
    """
    Gera um nome de arquivo base único para a anotação, incorporando a classe (pasta pai).
    Exemplo: 'Frames2Treinamento/Fire/frame_00003.jpg' -> 'Fire_frame_00003'
    """
    nome_base_imagem = os.path.splitext(os.path.basename(caminho_imagem))[0]
    nome_classe = os.path.basename(os.path.dirname(caminho_imagem))
    return f"{nome_classe}_{nome_base_imagem}"

def salvar_progresso_imagem(caminho_imagem):
    """Salva o caminho da última imagem em que o trabalho foi iniciado."""
    progresso = {'ultimo_caminho_imagem': caminho_imagem}
    with open(PROGRESS_FILE, 'w') as f:
        json.dump(progresso, f)

def carregar_progresso_imagem():
    """Carrega o caminho da última imagem em que o trabalho foi iniciado."""
    if not os.path.exists(PROGRESS_FILE):
        return None
    with open(PROGRESS_FILE, 'r') as f:
        try:
            progresso = json.load(f)
            return progresso.get('ultimo_caminho_imagem')
        except (json.JSONDecodeError, FileNotFoundError):
            return None

def salvar_anotacao_texto(caminho_imagem, indice_contorno, classe):
    """Salva a anotação de um contorno em um arquivo de texto específico e único da imagem."""
    nome_base_anotacao = gerar_nome_base_anotacao(caminho_imagem)
    nome_arquivo_anotacao = nome_base_anotacao + INCOMPLETE_SUFFIX
    caminho_arquivo_anotacao = os.path.join(ANNOTATIONS_FOLDER, nome_arquivo_anotacao)

    with open(caminho_arquivo_anotacao, 'a') as f:
        f.write(f"{indice_contorno},{classe}\n")


def carregar_anotacoes_anteriores(caminho_imagem):
    """Carrega os índices dos contornos já anotados para uma imagem específica."""
    nome_base_anotacao = gerar_nome_base_anotacao(caminho_imagem)
    nome_incompleto = nome_base_anotacao + INCOMPLETE_SUFFIX
    nome_completo = nome_base_anotacao + COMPLETE_SUFFIX
    caminho_incompleto = os.path.join(ANNOTATIONS_FOLDER, nome_incompleto)
    caminho_completo = os.path.join(ANNOTATIONS_FOLDER, nome_completo)

    caminho_arquivo_anotacao = None
    if os.path.exists(caminho_incompleto):
        caminho_arquivo_anotacao = caminho_incompleto
    elif os.path.exists(caminho_completo):
        caminho_arquivo_anotacao = caminho_completo

    indices_anotados = set()
    if caminho_arquivo_anotacao:
        with open(caminho_arquivo_anotacao, 'r') as f:
            for linha in f:
                try:
                    indice = int(linha.strip().split(',')[0])
                    indices_anotados.add(indice)
                except (ValueError, IndexError):
                    continue
    return indices_anotados

def marcar_anotacao_como_completa(caminho_imagem):
    """Renomeia o arquivo de anotação para indicar que todos os contornos foram processados."""
    nome_base_anotacao = gerar_nome_base_anotacao(caminho_imagem)
    nome_incompleto = nome_base_anotacao + INCOMPLETE_SUFFIX
    caminho_incompleto = os.path.join(ANNOTATIONS_FOLDER, nome_incompleto)

    if os.path.exists(caminho_incompleto):
        nome_completo = nome_base_anotacao + COMPLETE_SUFFIX
        caminho_completo = os.path.join(ANNOTATIONS_FOLDER, nome_completo)

        if os.path.exists(caminho_completo):
            os.remove(caminho_completo)

        os.rename(caminho_incompleto, caminho_completo)
        print(f"  Anotação para '{os.path.basename(caminho_imagem)}' marcada como completa.")


def encontrar_imagens_incompletas():
    """Verifica a pasta de anotações e retorna uma lista de imagens com anotações incompletas."""
    imagens_incompletas = []
    if not os.path.exists(ANNOTATIONS_FOLDER):
        return imagens_incompletas

    caminho_classe_1 = 'Frames2Treinamento/Fire/'
    caminho_classe_0 = 'Frames2Treinamento/Normal/'

    mapa_imagens_unicas = {}
    if os.path.exists(caminho_classe_1):
        for f in os.listdir(caminho_classe_1):
            nome_base = os.path.splitext(f)[0]
            chave = f"Fire_{nome_base}"
            mapa_imagens_unicas[chave] = os.path.join(caminho_classe_1, f)
    if os.path.exists(caminho_classe_0):
        for f in os.listdir(caminho_classe_0):
            nome_base = os.path.splitext(f)[0]
            chave = f"Normal_{nome_base}"
            mapa_imagens_unicas[chave] = os.path.join(caminho_classe_0, f)

    for f_name in os.listdir(ANNOTATIONS_FOLDER):
        if f_name.endswith(INCOMPLETE_SUFFIX):
            chave_anotacao = f_name.replace(INCOMPLETE_SUFFIX, '')
            if chave_anotacao in mapa_imagens_unicas:
                imagens_incompletas.append(mapa_imagens_unicas[chave_anotacao])
    return imagens_incompletas


def resetar_progresso(dataset_name='Datasets/dataset_anotado.h5'):
    """Apaga arquivos de progresso, anotações e o dataset para recomeçar do zero."""
    print("--- RESETANDO PROGRESSO ---")
    if os.path.exists(PROGRESS_FILE):
        os.remove(PROGRESS_FILE)
        print(f"Arquivo de progresso '{PROGRESS_FILE}' removido.")
    if os.path.exists(ANNOTATIONS_FOLDER):
        shutil.rmtree(ANNOTATIONS_FOLDER)
        print(f"Pasta de anotações '{ANNOTATIONS_FOLDER}' removida.")
    if os.path.exists(dataset_name):
        os.remove(dataset_name)
        print(f"Dataset HDF5 '{dataset_name}' removido.")
    print("\nProgresso de anotação resetado. Comece do início na próxima execução.")


def anotar_dataset_interativo(reset=False):
    """
    Processa imagens de forma interativa para anotação, salvando os resultados em arquivos de texto.
    Prioritiza a finalização de imagens marcadas como incompletas e permite voltar para corrigir a anotação anterior.
    """
    if reset:
        resetar_progresso()
        return

    os.makedirs(ANNOTATIONS_FOLDER, exist_ok=True)
    os.makedirs(os.path.dirname(PROGRESS_FILE), exist_ok=True)

    caminho_classe_1 = 'Frames2Treinamento/Fire/'
    caminho_classe_0 = 'Frames2Treinamento/Normal/'

    lista_classe_1 = [(os.path.join(caminho_classe_1, f), 'Fire') for f in sorted(os.listdir(caminho_classe_1))]
    lista_classe_0 = [(os.path.join(caminho_classe_0, f), 'Normal') for f in sorted(os.listdir(caminho_classe_0))]
    lista_completa = lista_classe_1 + lista_classe_0

    imagens_incompletas = encontrar_imagens_incompletas()
    if imagens_incompletas:
        print("--- ENCONTRADAS IMAGENS COM ANOTAÇÕES INCOMPLETAS ---")
        for img_path in imagens_incompletas:
            print(f"  - {os.path.basename(img_path)}")
        print("Finalize estas imagens primeiro.")

        lista_prioridade = [(path, 'Fire' if 'Fire' in path else 'Normal') for path in imagens_incompletas]
        caminhos_incompletos_set = set(imagens_incompletas)
        lista_restante = [item for item in lista_completa if item[0] not in caminhos_incompletos_set]
        lista_completa = lista_prioridade + lista_restante

    ultimo_caminho = carregar_progresso_imagem()
    pular_ate_encontrar = ultimo_caminho is not None and not imagens_incompletas

    print("\n--- INICIANDO ANOTAÇÃO INTERATIVA ---")
    print("  - 's': FUMAÇA (1) | 'n': NÃO FUMAÇA (0) | 'b': VOLTAR ANTERIOR")
    print("  - 'q': SAIR e SALVAR | 'i': IGNORAR contorno")
    print(f"Pasta de anotações: {ANNOTATIONS_FOLDER}")
    if pular_ate_encontrar:
        print(f"Continuando a partir da imagem: {os.path.basename(ultimo_caminho)}")
    print("-" * 50)

    for i, (caminho_img, tipo_pasta) in enumerate(lista_completa):
        if pular_ate_encontrar and caminho_img != ultimo_caminho:
            continue
        elif pular_ate_encontrar and caminho_img == ultimo_caminho:
            pular_ate_encontrar = False
            print(f"\nRetomando anotação na imagem: {caminho_img}")
        else:
            print(f"\nProcessando nova imagem {i+1}/{len(lista_completa)}: {caminho_img}")

        img = cv2.imread(caminho_img)
        if img is None: continue

        contornos, _ = extrair_contornos(img)
        if not contornos:
            marcar_anotacao_como_completa(caminho_img)
            continue

        anotacoes_feitas = carregar_anotacoes_anteriores(caminho_img)
        salvar_progresso_imagem(caminho_img)

        quit_pressed = False
        novas_anotacoes_da_imagem = []

        j = 0
        while j < len(contornos):
            if j in anotacoes_feitas:
                j += 1
                continue

            contorno = contornos[j]
            img_display = img.copy()
            cv2.drawContours(img_display, contornos, -1, (0, 255, 0), 1)
            cv2.drawContours(img_display, [contorno], -1, (0, 255, 255), 3)

            try:
                cv2.namedWindow('Anotador - (s/n/i/q/b)', cv2.WINDOW_MAXIMIZED)
            except AttributeError:
                cv2.namedWindow('Anotador - (s/n/i/q/b)', cv2.WINDOW_NORMAL)

            cv2.imshow('Anotador - (s/n/i/q/b)', img_display)
            key = cv2.waitKey(0) & 0xFF

            if key == ord('q'):
                print("\n'q' pressionado. Saindo da imagem atual...")
                quit_pressed = True
                break

            elif key == ord('b'):
                if novas_anotacoes_da_imagem:
                    indice_removido, _ = novas_anotacoes_da_imagem.pop()
                    print(f"  Anotação para o contorno {indice_removido + 1} removida. Voltando...")
                    j -= 1
                else:
                    print("  Nenhuma anotação nesta sessão para voltar. Tente o contorno anterior.")
                    if j > 0:
                        j -= 1
                continue

            elif key == ord('s'):
                novas_anotacoes_da_imagem.append((j, 1))
                print(f"  Contorno {j+1}/{len(contornos)}: Anotado como FUMAÇA (1)")
                j += 1

            elif key == ord('n'):
                novas_anotacoes_da_imagem.append((j, 0))
                print(f"  Contorno {j+1}/{len(contornos)}: Anotado como NÃO FUMAÇA (0)")
                j += 1

            elif key == ord('i'):
                print(f"  Contorno {j+1}/{len(contornos)}: Ignorado.")
                j += 1

            else:
                print(f"  Contorno {j+1}/{len(contornos)}: Tecla inválida, ignorado.")
                j += 1

        if novas_anotacoes_da_imagem:
            print(f"  Salvando {len(novas_anotacoes_da_imagem)} nova(s) anotação(ões) no arquivo de texto...")
            for indice_contorno, classe in novas_anotacoes_da_imagem:
                salvar_anotacao_texto(caminho_img, indice_contorno, classe)

        cv2.destroyAllWindows()

        total_anotado_final = len(carregar_anotacoes_anteriores(caminho_img))
        if not quit_pressed and total_anotado_final == len(contornos):
            marcar_anotacao_como_completa(caminho_img)

        if quit_pressed:
            break

    print("\nSessão de anotação concluída.")


def criar_dataset_h5(dataset_name='Datasets/dataset_features.h5', reset_h5=False):
    """
    Cria ou atualiza um dataset HDF5 a partir dos arquivos de anotação de texto.
    Processa apenas os arquivos marcados como 'completo'.
    """
    if reset_h5 and os.path.exists(dataset_name):
        os.remove(dataset_name)
        print(f"Dataset HDF5 '{dataset_name}' existente foi removido.")

    print("\n--- INICIANDO CRIAÇÃO DO DATASET HDF5 ---")

    features_list = []
    labels_list = []

    caminho_classe_1 = 'Frames2Treinamento/Fire/'
    caminho_classe_0 = 'Frames2Treinamento/Normal/'

    mapa_imagens_unicas = {}
    if os.path.exists(caminho_classe_1):
        for f in os.listdir(caminho_classe_1):
            nome_base = os.path.splitext(f)[0]
            chave = f"Fire_{nome_base}"
            mapa_imagens_unicas[chave] = os.path.join(caminho_classe_1, f)
    if os.path.exists(caminho_classe_0):
        for f in os.listdir(caminho_classe_0):
            nome_base = os.path.splitext(f)[0]
            chave = f"Normal_{nome_base}"
            mapa_imagens_unicas[chave] = os.path.join(caminho_classe_0, f)

    arquivos_anotacao = [f for f in os.listdir(ANNOTATIONS_FOLDER) if f.endswith(COMPLETE_SUFFIX)]

    if not arquivos_anotacao:
        print("Nenhum arquivo de anotação completo encontrado para processar.")
        return

    print(f"Encontrados {len(arquivos_anotacao)} arquivos de anotação completos.")

    for nome_arquivo_anotacao in arquivos_anotacao:
        # 'Fire_frame_00003_completo.txt' -> 'Fire_frame_00003'
        chave_anotacao = nome_arquivo_anotacao.replace(COMPLETE_SUFFIX, '')
        caminho_img = mapa_imagens_unicas.get(chave_anotacao)

        if not caminho_img or not os.path.exists(caminho_img):
            print(f"Aviso: Imagem original para '{nome_arquivo_anotacao}' não encontrada. Pulando.")
            continue

        img = cv2.imread(caminho_img)
        if img is None:
            print(f"Aviso: Não foi possível ler a imagem '{caminho_img}'. Pulando.")
            continue

        contornos, img_hsv = extrair_contornos(img)

        caminho_arquivo_anotacao = os.path.join(ANNOTATIONS_FOLDER, nome_arquivo_anotacao)
        with open(caminho_arquivo_anotacao, 'r') as f:
            for linha in f:
                try:
                    indice_contorno, classe = map(int, linha.strip().split(','))
                    if 0 <= indice_contorno < len(contornos):
                        features = extrair_features(img_hsv, contornos[indice_contorno])
                        if features is not None and features.shape[0] == NUM_FEATURES:
                            features_list.append(features)
                            labels_list.append(classe)
                        else:
                            nome_base_img = os.path.basename(caminho_img)
                            print(f"  -> Aviso: Falha ao extrair features para contorno {indice_contorno} da imagem {nome_base_img}.")
                except (ValueError, IndexError):
                    continue

    if not features_list:
        print("\nNenhuma amostra válida foi extraída das anotações.")
        return

    X_data = np.array(features_list, dtype=np.float32)
    y_data = np.array(labels_list, dtype=np.int8)

    os.makedirs(os.path.dirname(dataset_name), exist_ok=True)
    with h5py.File(dataset_name, 'w') as hf:
        print(f"\nCriando novo dataset consolidado com {len(X_data)} amostras...")
        hf.create_dataset('features', data=X_data, compression="gzip", chunks=True, maxshape=(None, NUM_FEATURES))
        hf.create_dataset('labels', data=y_data, compression="gzip", chunks=True, maxshape=(None,))

    print("Operação concluída com sucesso!")
    print(f"Dataset salvo em: {dataset_name}")
    print(f"Dimensões totais: features={X_data.shape}, labels={y_data.shape}")

# %%
anotar_dataset_interativo(reset = False)
# Out:
# --- INICIANDO ANOTAÇÃO INTERATIVA ---
#   - 's': FUMAÇA (1) | 'n': NÃO FUMAÇA (0) | 'b': VOLTAR ANTERIOR
#   - 'q': SAIR e SALVAR | 'i': IGNORAR contorno
# Pasta de anotações: Anotacoes_Texto/
# Continuando a partir da imagem: frame_00267.jpg
# --------------------------------------------------
#
# Retomando anotação na imagem: Frames2Treinamento/Fire/frame_00267.jpg
#   Contorno 1/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 2/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 3/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 4/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 5/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 6/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 7/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 8/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 9/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 10/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 11/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 12/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 13/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 14/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 15/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 16/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 17/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 18/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 19/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 20/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 21/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 22/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 23/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 24/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 25/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 26/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 27/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 28/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 29/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 30/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 31/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 32/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 33/84: Anotado como FUMAÇA (1)
#   Contorno 34/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 35/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 36/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 37/84: Anotado como FUMAÇA (1)
#   Contorno 38/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 39/84: Anotado como FUMAÇA (1)
#   Contorno 40/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 41/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 42/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 43/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 44/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 45/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 46/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 47/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 48/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 49/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 50/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 51/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 52/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 53/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 54/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 55/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 56/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 57/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 58/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 59/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 60/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 61/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 62/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 63/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 64/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 65/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 66/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 67/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 68/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 69/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 70/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 71/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 72/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 73/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 74/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 75/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 76/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 77/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 78/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 79/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 80/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 81/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 82/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 83/84: Anotado como NÃO FUMAÇA (0)
#   Contorno 84/84: Anotado como FUMAÇA (1)
#   Salvando 84 nova(s) anotação(ões) no arquivo de texto...
#   Anotação para 'frame_00267.jpg' marcada como completa.
#
# Processando nova imagem 66/1000: Frames2Treinamento/Fire/frame_00271.jpg
#   Contorno 1/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 2/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 3/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 4/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 5/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 6/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 7/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 8/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 9/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 10/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 11/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 12/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 13/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 14/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 15/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 16/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 17/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 18/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 19/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 20/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 21/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 22/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 23/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 24/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 25/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 26/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 27/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 28/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 29/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 30/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 31/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 32/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 33/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 34/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 35/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 36/91: Anotado como FUMAÇA (1)
#   Contorno 37/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 38/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 39/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 40/91: Anotado como FUMAÇA (1)
#   Contorno 41/91: Anotado como FUMAÇA (1)
#   Contorno 42/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 43/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 44/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 45/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 46/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 47/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 48/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 49/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 50/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 51/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 52/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 53/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 54/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 55/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 56/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 57/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 58/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 59/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 60/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 61/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 62/91: Anotado como NÃO FUMAÇA (0)
#   Anotação para o contorno 62 removida. Voltando...
#   Contorno 62/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 63/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 64/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 65/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 66/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 67/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 68/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 69/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 70/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 71/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 72/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 73/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 74/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 75/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 76/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 77/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 78/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 79/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 80/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 81/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 82/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 83/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 84/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 85/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 86/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 87/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 88/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 89/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 90/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 91/91: Anotado como FUMAÇA (1)
#   Salvando 91 nova(s) anotação(ões) no arquivo de texto...
#   Anotação para 'frame_00271.jpg' marcada como completa.
#
# Processando nova imagem 67/1000: Frames2Treinamento/Fire/frame_00281.jpg
#   Contorno 1/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 2/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 3/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 4/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 5/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 6/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 7/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 8/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 9/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 10/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 11/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 12/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 13/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 14/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 15/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 16/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 17/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 18/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 19/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 20/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 21/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 22/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 23/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 24/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 25/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 26/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 27/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 28/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 29/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 30/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 31/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 32/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 33/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 34/91: Anotado como FUMAÇA (1)
#   Contorno 35/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 36/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 37/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 38/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 39/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 40/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 41/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 42/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 43/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 44/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 45/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 46/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 47/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 48/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 49/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 50/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 51/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 52/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 53/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 54/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 55/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 56/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 57/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 58/91: Anotado como FUMAÇA (1)
#   Contorno 59/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 60/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 61/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 62/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 63/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 64/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 65/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 66/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 67/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 68/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 69/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 70/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 71/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 72/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 73/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 74/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 75/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 76/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 77/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 78/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 79/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 80/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 81/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 82/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 83/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 84/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 85/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 86/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 87/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 88/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 89/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 90/91: Anotado como NÃO FUMAÇA (0)
#   Contorno 91/91: Anotado como FUMAÇA (1)
#   Salvando 91 nova(s) anotação(ões) no arquivo de texto...
#   Anotação para 'frame_00281.jpg' marcada como completa.
#
# Processando nova imagem 68/1000: Frames2Treinamento/Fire/frame_00285.jpg
#   Contorno 1/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 2/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 3/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 4/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 5/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 6/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 7/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 8/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 9/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 10/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 11/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 12/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 13/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 14/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 15/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 16/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 17/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 18/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 19/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 20/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 21/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 22/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 23/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 24/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 25/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 26/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 27/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 28/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 29/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 30/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 31/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 32/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 33/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 34/104: Anotado como NÃO FUMAÇA (0)
#   Anotação para o contorno 34 removida. Voltando...
#   Contorno 34/104: Anotado como FUMAÇA (1)
#   Contorno 35/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 36/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 37/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 38/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 39/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 40/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 41/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 42/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 43/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 44/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 45/104: Anotado como FUMAÇA (1)
#   Contorno 46/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 47/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 48/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 49/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 50/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 51/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 52/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 53/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 54/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 55/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 56/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 57/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 58/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 59/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 60/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 61/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 62/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 63/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 64/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 65/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 66/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 67/104: Anotado como FUMAÇA (1)
#   Contorno 68/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 69/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 70/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 71/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 72/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 73/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 74/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 75/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 76/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 77/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 78/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 79/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 80/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 81/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 82/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 83/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 84/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 85/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 86/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 87/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 88/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 89/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 90/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 91/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 92/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 93/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 94/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 95/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 96/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 97/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 98/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 99/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 100/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 101/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 102/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 103/104: Anotado como NÃO FUMAÇA (0)
#   Contorno 104/104: Anotado como FUMAÇA (1)
#   Salvando 104 nova(s) anotação(ões) no arquivo de texto...
#   Anotação para 'frame_00285.jpg' marcada como completa.
#
# Processando nova imagem 69/1000: Frames2Treinamento/Fire/frame_00287.jpg
#   Contorno 1/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 2/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 3/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 4/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 5/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 6/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 7/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 8/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 9/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 10/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 11/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 12/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 13/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 14/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 15/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 16/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 17/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 18/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 19/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 20/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 21/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 22/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 23/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 24/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 25/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 26/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 27/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 28/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 29/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 30/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 31/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 32/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 33/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 34/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 35/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 36/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 37/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 38/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 39/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 40/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 41/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 42/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 43/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 44/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 45/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 46/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 47/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 48/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 49/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 50/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 51/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 52/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 53/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 54/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 55/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 56/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 57/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 58/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 59/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 60/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 61/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 62/93: Anotado como FUMAÇA (1)
#   Contorno 63/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 64/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 65/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 66/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 67/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 68/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 69/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 70/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 71/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 72/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 73/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 74/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 75/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 76/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 77/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 78/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 79/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 80/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 81/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 82/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 83/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 84/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 85/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 86/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 87/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 88/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 89/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 90/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 91/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 92/93: Anotado como NÃO FUMAÇA (0)
#   Contorno 93/93: Anotado como FUMAÇA (1)
#   Salvando 93 nova(s) anotação(ões) no arquivo de texto...
#   Anotação para 'frame_
96: Anotado como NÃO FUMAÇA (0)
#   Contorno 17/96: Anotado como FUMAÇA (1)
#   Contorno 18/96: Anotado como FUMAÇA (1)
#   Contorno 19/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 20/96: Anotado como FUMAÇA (1)
#   Contorno 21/96: Anotado como FUMAÇA (1)
#   Contorno 22/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 23/96: Anotado como FUMAÇA (1)
#   Contorno 24/96: Anotado como FUMAÇA (1)
#   Contorno 25/96: Anotado como FUMAÇA (1)
#   Contorno 26/96: Anotado como FUMAÇA (1)
#   Contorno 27/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 28/96: Anotado como FUMAÇA (1)
#   Contorno 29/96: Anotado como FUMAÇA (1)
#   Contorno 30/96: Anotado como FUMAÇA (1)
#   Contorno 31/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 32/96: Anotado como FUMAÇA (1)
#   Contorno 33/96: Anotado como FUMAÇA (1)
#   Contorno 34/96: Anotado como FUMAÇA (1)
#   Contorno 35/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 36/96: Anotado como FUMAÇA (1)
#   Contorno 37/96: Anotado como FUMAÇA (1)
#   Contorno 38/96: Anotado como FUMAÇA (1)
#   Contorno 39/96: Anotado como FUMAÇA (1)
#   Contorno 40/96: Anotado como FUMAÇA (1)
#   Contorno 41/96: Anotado como FUMAÇA (1)
#   Contorno 42/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 43/96: Anotado como FUMAÇA (1)
#   Contorno 44/96: Anotado como FUMAÇA (1)
#   Contorno 45/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 46/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 47/96: Anotado como FUMAÇA (1)
#   Contorno 48/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 49/96: Anotado como FUMAÇA (1)
#   Contorno 50/96: Anotado como FUMAÇA (1)
#   Contorno 51/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 52/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 53/96: Anotado como FUMAÇA (1)
#   Contorno 54/96: Anotado como FUMAÇA (1)
#   Contorno 55/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 56/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 57/96: Anotado como FUMAÇA (1)
#   Contorno 58/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 59/96: Anotado como FUMAÇA (1)
#   Contorno 60/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 61/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 62/96: Anotado como FUMAÇA (1)
#   Contorno 63/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 64/96: Anotado como FUMAÇA (1)
#   Contorno 65/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 66/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 67/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 68/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 69/96: Anotado como FUMAÇA (1)
#   Contorno 70/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 71/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 72/96: Anotado como FUMAÇA (1)
#   Contorno 73/96: Anotado como FUMAÇA (1)
#   Contorno 74/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 75/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 76/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 77/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 78/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 79/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 80/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 81/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 82/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 83/96: Anotado como FUMAÇA (1)
#   Contorno 84/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 85/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 86/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 87/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 88/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 89/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 90/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 91/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 92/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 93/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 94/96: Anotado como NÃO FUMAÇA (0)
#   Contorno 95/96: Anotado como FUMAÇA (1)
#   Contorno 96/96: Anotado como FUMAÇA (1)
#   Salvando 96 nova(s) anotação(ões) no arquivo de texto...
#   Anotação para 'frame_00582.jpg' marcada como completa.
#
# Processando nova imagem 155/1000: Frames2Treinamento/Fire/frame_00586.jpg
#
# 'q' pressionado. Saindo da imagem atual...
#
# Sessão de anotação concluída.

# %%
scriar_dataset_h5(reset_h5 = True)
# Out:
# Dataset HDF5 'Datasets/dataset_features.h5' existente foi removido.
#
# --- INICIANDO CRIAÇÃO DO DATASET HDF5 ---
# Encontrados 2 arquivos de anotação completos.
#
# Criando novo dataset consolidado com 52 amostras...
# Operação concluída com sucesso!
# Dataset salvo em: Datasets/dataset_features.h5
# Dimensões totais: features=(52, 15), labels=(52,)
